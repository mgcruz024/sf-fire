# %% [markdown]
# 1. Load in sample Fire Incidents CSV
# 2. Create subsets based on "exploring_OpenSF.py"
# 3. Have separate code blocks for each subset, and call on a function that generates a P-SQL create table script
